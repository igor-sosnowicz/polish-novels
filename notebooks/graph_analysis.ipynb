# %% [markdown]
# # Graph analysis report

# %% [markdown]
# This notebook is generated from the graph CSV files in `data/graphs/`.
#
# It includes per-book metrics, per-epoch aggregation, pairwise comparisons, and representative plots generated by `GraphAnalyser`.

# %%
from pathlib import Path
import pandas as pd
from IPython.display import display

summary = pd.read_csv(Path('graph_metrics_summary.csv'))
epoch_summary = pd.read_csv(Path('epoch_metrics_summary.csv'))
display(summary)
display(epoch_summary)

# %% [markdown]
# ## Epoch: barok

# %% [markdown]
# **Representative book:** don_kichot_z_la_manchy
#
# Books:
# - cnotliwi
# - don_kichot_z_la_manchy
# - pamietniki
# - pascal_mysli
# - potocki_transakcja_wojny_chocimskiej
# - prowincjalki
# **Representative plots**
#
# - - degree_histogram: `plots/don_kichot_z_la_manchy_degree_histogram.png`
# - - degree: `plots/don_kichot_z_la_manchy_degree_graph.png`
# - - page_rank: `plots/don_kichot_z_la_manchy_page_rank_graph.png`
# - - betweeness: `plots/don_kichot_z_la_manchy_betweeness_graph.png`
# - - closeness: `plots/don_kichot_z_la_manchy_closeness_graph.png`
# - - absolute_relationshipscore: `plots/don_kichot_z_la_manchy_absolute_relationshipscore_graph.png`
# ![barok representative graph](plots/don_kichot_z_la_manchy_page_rank_graph.png)

# %% [markdown]
# ### Per-book metrics
#
# | book | diameter | max_degree | page_rank | protagonist_count | antagonist_count |
# | --- | ---: | ---: | ---: | ---: | ---: |
# | cnotliwi | 11.0 | 67 | 0.0016474464579901151 | 293 | 140 |
# | don_kichot_z_la_manchy | 12.0 | 472 | 0.0008196721311475429 | 472 | 305 |
# | pamietniki | 16.0 | 56 | 0.0015503875968992248 | 203 | 202 |
# | pascal_mysli | 11.0 | 26 | 0.0025 | 99 | 146 |
# | potocki_transakcja_wojny_chocimskiej | 10.0 | 34 | 0.004405286343612336 | 69 | 87 |
# | prowincjalki | 11.0 | 42 | 0.0029069767441860465 | 48 | 155 |

# %% [markdown]
# ## Epoch: mloda-polska-modernizm

# %% [markdown]
# **Representative book:** brzozowski_plomienie
#
# Books:
# - berent_prochno
# - brzozowski_plomienie
# **Representative plots**
#
# - - degree_histogram: `plots/brzozowski_plomienie_degree_histogram.png`
# - - degree: `plots/brzozowski_plomienie_degree_graph.png`
# - - page_rank: `plots/brzozowski_plomienie_page_rank_graph.png`
# - - betweeness: `plots/brzozowski_plomienie_betweeness_graph.png`
# - - closeness: `plots/brzozowski_plomienie_closeness_graph.png`
# - - absolute_relationshipscore: `plots/brzozowski_plomienie_absolute_relationshipscore_graph.png`
# ![mloda-polska-modernizm representative graph](plots/brzozowski_plomienie_page_rank_graph.png)

# %% [markdown]
# ### Per-book metrics
#
# | book | diameter | max_degree | page_rank | protagonist_count | antagonist_count |
# | --- | ---: | ---: | ---: | ---: | ---: |
# | berent_prochno | 9.0 | 72 | 0.002109704641350211 | 133 | 172 |
# | brzozowski_plomienie | 13.0 | 103 | 0.0008058017727638999 | 319 | 479 |

# %% [markdown]
# ## Epoch: modernizm

# %% [markdown]
# **Representative book:** alejchem_z_jarmarku
#
# Books:
# - alejchem_z_jarmarku
# - amicis_serce
# - conrad_nostromo
# **Representative plots**
#
# - - degree_histogram: `plots/alejchem_z_jarmarku_degree_histogram.png`
# - - degree: `plots/alejchem_z_jarmarku_degree_graph.png`
# - - page_rank: `plots/alejchem_z_jarmarku_page_rank_graph.png`
# - - betweeness: `plots/alejchem_z_jarmarku_betweeness_graph.png`
# - - closeness: `plots/alejchem_z_jarmarku_closeness_graph.png`
# - - absolute_relationshipscore: `plots/alejchem_z_jarmarku_absolute_relationshipscore_graph.png`
# ![modernizm representative graph](plots/alejchem_z_jarmarku_page_rank_graph.png)

# %% [markdown]
# ### Per-book metrics
#
# | book | diameter | max_degree | page_rank | protagonist_count | antagonist_count |
# | --- | ---: | ---: | ---: | ---: | ---: |
# | alejchem_z_jarmarku | 14.0 | 198 | 0.0009990009990009988 | 418 | 241 |
# | amicis_serce | 11.0 | 66 | 0.0012048192771084338 | 488 | 114 |
# | conrad_nostromo | 11.0 | 125 | 0.0011376564277588166 | 278 | 273 |

# %% [markdown]
# ## Epoch: pozytywizm

# %% [markdown]
# **Representative book:** chata_za_wsia
#
# Books:
# - 20_000_mil_podmorskiej_zeglugi
# - bez_dogmatu
# - chata_za_wsia
# - darwin_o_powstawaniu_gatunkow
# **Representative plots**
#
# - - degree_histogram: `plots/chata_za_wsia_degree_histogram.png`
# - - degree: `plots/chata_za_wsia_degree_graph.png`
# - - page_rank: `plots/chata_za_wsia_page_rank_graph.png`
# - - betweeness: `plots/chata_za_wsia_betweeness_graph.png`
# - - closeness: `plots/chata_za_wsia_closeness_graph.png`
# - - absolute_relationshipscore: `plots/chata_za_wsia_absolute_relationshipscore_graph.png`
# ![pozytywizm representative graph](plots/chata_za_wsia_page_rank_graph.png)

# %% [markdown]
# ### Per-book metrics
#
# | book | diameter | max_degree | page_rank | protagonist_count | antagonist_count |
# | --- | ---: | ---: | ---: | ---: | ---: |
# | 20_000_mil_podmorskiej_zeglugi | 9.0 | 77 | 0.0020618556701030933 | 151 | 82 |
# | bez_dogmatu | 7.0 | 111 | 0.0026881720430107525 | 174 | 83 |
# | chata_za_wsia | 9.0 | 128 | 0.0013698630136986301 | 248 | 231 |
# | darwin_o_powstawaniu_gatunkow | 9.0 | 12 | 0.0030959752321981426 | 46 | 88 |

# %% [markdown]
# ## Epoch: renesans

# %% [markdown]
# **Representative book:** gargantua_i_pantagruel
#
# Books:
# - gargantua_i_pantagruel
# - o_poprawie_rzeczypospolitej
# - proby_ksiega_druga
# - proby_ksiega_pierwsza
# - proby_ksiega_trzecia
# **Representative plots**
#
# - - degree_histogram: `plots/gargantua_i_pantagruel_degree_histogram.png`
# - - degree: `plots/gargantua_i_pantagruel_degree_graph.png`
# - - page_rank: `plots/gargantua_i_pantagruel_page_rank_graph.png`
# - - betweeness: `plots/gargantua_i_pantagruel_betweeness_graph.png`
# - - closeness: `plots/gargantua_i_pantagruel_closeness_graph.png`
# - - absolute_relationshipscore: `plots/gargantua_i_pantagruel_absolute_relationshipscore_graph.png`
# ![renesans representative graph](plots/gargantua_i_pantagruel_page_rank_graph.png)

# %% [markdown]
# ### Per-book metrics
#
# | book | diameter | max_degree | page_rank | protagonist_count | antagonist_count |
# | --- | ---: | ---: | ---: | ---: | ---: |
# | gargantua_i_pantagruel | 17.0 | 251 | 0.0005216484089723527 | 474 | 526 |
# | o_poprawie_rzeczypospolitej | 6.0 | 7 | 0.005076142131979695 | 46 | 68 |
# | proby_ksiega_druga | 20.0 | 17 | 0.0011890606420927466 | 229 | 253 |
# | proby_ksiega_pierwsza | 15.0 | 37 | 0.0011876484560570072 | 174 | 272 |
# | proby_ksiega_trzecia | 13.0 | 25 | 0.00234192037470726 | 98 | 150 |

# %% [markdown]
# ## Epoch: romantyzm

# %% [markdown]
# **Representative book:** balzac_komedia_ludzka_stracone_zludzenia_wielki_czlowiek_z_prowincji
#
# Books:
# - aleksander_dumas_trzej_muszkieterowie_tom_2
# - andersen_tylko_grajek
# - balzac_komedia_ludzka_jaszczur
# - balzac_komedia_ludzka_stracone_zludzenia_wielki_czlowiek_z_prowincji
# - bronte_dziwne_losy_jane_eyre
# **Representative plots**
#
# - - degree_histogram: `plots/balzac_komedia_ludzka_stracone_zludzenia_wielki_czlowiek_z_prowincji_degree_histogram.png`
# - - degree: `plots/balzac_komedia_ludzka_stracone_zludzenia_wielki_czlowiek_z_prowincji_degree_graph.png`
# - - page_rank: `plots/balzac_komedia_ludzka_stracone_zludzenia_wielki_czlowiek_z_prowincji_page_rank_graph.png`
# - - betweeness: `plots/balzac_komedia_ludzka_stracone_zludzenia_wielki_czlowiek_z_prowincji_betweeness_graph.png`
# - - closeness: `plots/balzac_komedia_ludzka_stracone_zludzenia_wielki_czlowiek_z_prowincji_closeness_graph.png`
# - - absolute_relationshipscore: `plots/balzac_komedia_ludzka_stracone_zludzenia_wielki_czlowiek_z_prowincji_absolute_relationshipscore_graph.png`
# ![romantyzm representative graph](plots/balzac_komedia_ludzka_stracone_zludzenia_wielki_czlowiek_z_prowincji_page_rank_graph.png)

# %% [markdown]
# ### Per-book metrics
#
# | book | diameter | max_degree | page_rank | protagonist_count | antagonist_count |
# | --- | ---: | ---: | ---: | ---: | ---: |
# | aleksander_dumas_trzej_muszkieterowie_tom_2 | 9.0 | 126 | 0.0014684287812041115 | 227 | 185 |
# | andersen_tylko_grajek | 8.0 | 146 | 0.0014970059880239528 | 278 | 126 |
# | balzac_komedia_ludzka_jaszczur | 7.0 | 142 | 0.0024875621890547263 | 0 | 0 |
# | balzac_komedia_ludzka_stracone_zludzenia_wielki_czlowiek_z_prowincji | 9.0 | 216 | 0.0017301038062283764 | 207 | 125 |
# | bronte_dziwne_losy_jane_eyre | 10.0 | 165 | 0.0010718113612004287 | 415 | 200 |

# %% [markdown]
# ## Pairwise epoch comparisons

# %% [markdown]
# ### barok vs mloda-polska-modernizm
#
# ![barok__vs__mloda-polska-modernizm](notebooks/plots/compare_barok_vs_mloda-polska-modernizm.png)

# %% [markdown]
# ### barok vs modernizm
#
# ![barok__vs__modernizm](notebooks/plots/compare_barok_vs_modernizm.png)

# %% [markdown]
# ### barok vs pozytywizm
#
# ![barok__vs__pozytywizm](notebooks/plots/compare_barok_vs_pozytywizm.png)

# %% [markdown]
# ### barok vs renesans
#
# ![barok__vs__renesans](notebooks/plots/compare_barok_vs_renesans.png)

# %% [markdown]
# ### barok vs romantyzm
#
# ![barok__vs__romantyzm](notebooks/plots/compare_barok_vs_romantyzm.png)

# %% [markdown]
# ### mloda-polska-modernizm vs modernizm
#
# ![mloda-polska-modernizm__vs__modernizm](notebooks/plots/compare_mloda-polska-modernizm_vs_modernizm.png)

# %% [markdown]
# ### mloda-polska-modernizm vs pozytywizm
#
# ![mloda-polska-modernizm__vs__pozytywizm](notebooks/plots/compare_mloda-polska-modernizm_vs_pozytywizm.png)

# %% [markdown]
# ### mloda-polska-modernizm vs renesans
#
# ![mloda-polska-modernizm__vs__renesans](notebooks/plots/compare_mloda-polska-modernizm_vs_renesans.png)

# %% [markdown]
# ### mloda-polska-modernizm vs romantyzm
#
# ![mloda-polska-modernizm__vs__romantyzm](notebooks/plots/compare_mloda-polska-modernizm_vs_romantyzm.png)

# %% [markdown]
# ### modernizm vs pozytywizm
#
# ![modernizm__vs__pozytywizm](notebooks/plots/compare_modernizm_vs_pozytywizm.png)

# %% [markdown]
# ### modernizm vs renesans
#
# ![modernizm__vs__renesans](notebooks/plots/compare_modernizm_vs_renesans.png)

# %% [markdown]
# ### modernizm vs romantyzm
#
# ![modernizm__vs__romantyzm](notebooks/plots/compare_modernizm_vs_romantyzm.png)

# %% [markdown]
# ### pozytywizm vs renesans
#
# ![pozytywizm__vs__renesans](notebooks/plots/compare_pozytywizm_vs_renesans.png)

# %% [markdown]
# ### pozytywizm vs romantyzm
#
# ![pozytywizm__vs__romantyzm](notebooks/plots/compare_pozytywizm_vs_romantyzm.png)

# %% [markdown]
# ### renesans vs romantyzm
#
# ![renesans__vs__romantyzm](notebooks/plots/compare_renesans_vs_romantyzm.png)
